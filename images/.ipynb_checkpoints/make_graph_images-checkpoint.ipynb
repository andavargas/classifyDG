# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g = nx.Graph()

# %%
g = nx.generators.directed.random_k_out_graph(5,1,1,self_loops=True)
nx.draw(g, arrowsize=20)
plt.show()
print(nx.is_directed_acyclic_graph(g))
# Out:
# False

# %%
g = nx.generators.directed.random_k_out_graph(5,2,1,self_loops=False)
nx.draw(g, arrowsize=20)
plt.show()
